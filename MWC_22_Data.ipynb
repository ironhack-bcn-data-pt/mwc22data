# %% [markdown]
# # MWC 22 | data science Hackaton

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#ENTORNO" data-toc-modified-id="ENTORNO-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>ENTORNO</a></span></li><li><span><a href="#IMPORTAR-DATOS" data-toc-modified-id="IMPORTAR-DATOS-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>IMPORTAR DATOS</a></span><ul class="toc-item"><li><span><a href="#Dataset-de-clientes-'CLIENT-TABLE'" data-toc-modified-id="Dataset-de-clientes-'CLIENT-TABLE'-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Dataset de clientes 'CLIENT TABLE'</a></span></li><li><span><a href="#El-dataset-de-pedidos-'ORDERS-TABLE'" data-toc-modified-id="El-dataset-de-pedidos-'ORDERS-TABLE'-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>El dataset de pedidos 'ORDERS TABLE'</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Dataset-de-Clientes" data-toc-modified-id="Dataset-de-Clientes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Dataset de Clientes</a></span><ul class="toc-item"><li><span><a href="#Exploración-Inicial" data-toc-modified-id="Exploración-Inicial-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Exploración Inicial</a></span></li><li><span><a href="#Variables" data-toc-modified-id="Variables-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Variables</a></span><ul class="toc-item"><li><span><a href="#CLIENT_ID" data-toc-modified-id="CLIENT_ID-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>CLIENT_ID</a></span></li><li><span><a href="#CLIENT_SEGMENT-(TARGET)" data-toc-modified-id="CLIENT_SEGMENT-(TARGET)-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>CLIENT_SEGMENT (TARGET)</a></span></li><li><span><a href="#AVG_CONSO_MONTH" data-toc-modified-id="AVG_CONSO_MONTH-2.1.2.3"><span class="toc-item-num">2.1.2.3&nbsp;&nbsp;</span>AVG_CONSO_MONTH</a></span></li><li><span><a href="#AVG_BASKET_SIZE" data-toc-modified-id="AVG_BASKET_SIZE-2.1.2.4"><span class="toc-item-num">2.1.2.4&nbsp;&nbsp;</span>AVG_BASKET_SIZE</a></span></li><li><span><a href="#RECEIVED_COMMUNICATION" data-toc-modified-id="RECEIVED_COMMUNICATION-2.1.2.5"><span class="toc-item-num">2.1.2.5&nbsp;&nbsp;</span>RECEIVED_COMMUNICATION</a></span></li></ul></li><li><span><a href="#Correlaciones" data-toc-modified-id="Correlaciones-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Correlaciones</a></span></li></ul></li><li><span><a href="#Dataset-de-Orders" data-toc-modified-id="Dataset-de-Orders-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Dataset de Orders</a></span><ul class="toc-item"><li><span><a href="#Exploración-Inicial" data-toc-modified-id="Exploración-Inicial-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Exploración Inicial</a></span></li><li><span><a href="#Variables" data-toc-modified-id="Variables-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Variables</a></span><ul class="toc-item"><li><span><a href="#CLIENT_ID" data-toc-modified-id="CLIENT_ID-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>CLIENT_ID</a></span></li><li><span><a href="#NUM_PRODS" data-toc-modified-id="NUM_PRODS-2.2.2.2"><span class="toc-item-num">2.2.2.2&nbsp;&nbsp;</span>NUM_PRODS</a></span></li><li><span><a href="#ORDER_ID" data-toc-modified-id="ORDER_ID-2.2.2.3"><span class="toc-item-num">2.2.2.3&nbsp;&nbsp;</span>ORDER_ID</a></span></li><li><span><a href="#FRUIT_PRODUCT" data-toc-modified-id="FRUIT_PRODUCT-2.2.2.4"><span class="toc-item-num">2.2.2.4&nbsp;&nbsp;</span>FRUIT_PRODUCT</a></span></li></ul></li></ul></li><li><span><a href="#Juntamos-las-tablas" data-toc-modified-id="Juntamos-las-tablas-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Juntamos las tablas</a></span><ul class="toc-item"><li><span><a href="#Received-comunication" data-toc-modified-id="Received-comunication-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Received comunication</a></span></li></ul></li></ul></li><li><span><a href="#PREDICCIÓN-SEGMENTOS" data-toc-modified-id="PREDICCIÓN-SEGMENTOS-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>PREDICCIÓN SEGMENTOS</a></span><ul class="toc-item"><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Train Test Split</a></span></li><li><span><a href="#Separabilidad-de-las-clases" data-toc-modified-id="Separabilidad-de-las-clases-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Separabilidad de las clases</a></span></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Random Forest Classifier</a></span></li><li><span><a href="#Gradient-Boosting" data-toc-modified-id="Gradient-Boosting-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Gradient Boosting</a></span></li><li><span><a href="#ExtraTreeClassifier" data-toc-modified-id="ExtraTreeClassifier-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>ExtraTreeClassifier</a></span></li><li><span><a href="#Standard-Scaler" data-toc-modified-id="Standard-Scaler-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Standard Scaler</a></span></li><li><span><a href="#Grsadient-Boosting-Fine-Tunning" data-toc-modified-id="Grsadient-Boosting-Fine-Tunning-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Grsadient Boosting Fine Tunning</a></span></li></ul></li><li><span><a href="#Resultados" data-toc-modified-id="Resultados-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Resultados</a></span></li></ul></div>

# %% [markdown]
# ## ENTORNO

# %%
## Dataframes
import pandas as pd
import numpy as np

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib import rcParams
rcParams['figure.figsize'] = 11.7,8.27

#Models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, recall_score, precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import auc, roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.manifold import TSNE
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler

# %% [markdown]
# ## IMPORTAR DATOS

# %% [markdown]
# ### Dataset de clientes 'CLIENT TABLE'

# %%
clients = pd.read_csv("data/mwc22-client_table.csv")

# %%
clients.head()
# Out:
#    CLIENT ID  CLIENT_SEGMENT AVG CONSO AVG BASKET SIZE  RECEIVED_COMMUNICATION
# 0   24321771               6     67,25          201,75                       0
# 1   24321859               2     58,33             350                       0
# 2   24321880               3     46,67             112                       0
# 3   24321957               2        50             600                       0
# 4   24321962               4        10             120                       0

# %%
clients.tail()
# Out:
#        CLIENT ID  CLIENT_SEGMENT AVG CONSO AVG BASKET SIZE  \
# 35879   48345531               4      12,5             150
# 35880   48345686               3      37,5           112,5
# 35881   48365750               3     41,67             125
# 35882   48365861               3     62,58          125,17
# 35883   48365940               1     89,17          152,86
#
#        RECEIVED_COMMUNICATION
# 35879                       1
# 35880                       1
# 35881                       1
# 35882                       1
# 35883                       1

# %% [markdown]
# ### El dataset de pedidos 'ORDERS TABLE'

# %%
orders = pd.read_csv("data/mwc22-orders_table.csv")

# %%
orders.head()
# Out:
#    CLIENT ID  NB PRODS   ORDER ID FRUIT_PRODUCT
# 0   18070505         5  671907264         Apple
# 1   18070505        10  671907264        Orange
# 2   18070505         5  671907264          Kiwi
# 3   18070505        10  671907264          Pear
# 4   18070505         5  671907264        Cheery

# %%
orders.tail()
# Out:
#        CLIENT ID  NB PRODS   ORDER ID FRUIT_PRODUCT
# 66907   48352045         2  670065547     Pineapple
# 66908   48352045         1  670065547         Apple
# 66909   48352045         2  670065547    Watermelon
# 66910   48352045         1  670065547         Grape
# 66911   48352045         1  670065547          Plum

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Dataset de Clientes

# %% [markdown]
# #### Exploración Inicial

# %%
clients.head()
# Out:
#    CLIENT ID  CLIENT_SEGMENT AVG CONSO AVG BASKET SIZE  RECEIVED_COMMUNICATION
# 0   24321771               6     67,25          201,75                       0
# 1   24321859               2     58,33             350                       0
# 2   24321880               3     46,67             112                       0
# 3   24321957               2        50             600                       0
# 4   24321962               4        10             120                       0

# %%
clients.shape
# Out:
# (35884, 5)

# %% [markdown]
# El dataset de orders tiene 35.844 registros y 5 variables.

# %%
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35884 entries, 0 to 35883
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLIENT ID               35884 non-null  int64
#  1   CLIENT_SEGMENT          35884 non-null  int64
#  2   AVG CONSO               35884 non-null  object
#  3   AVG BASKET SIZE         35884 non-null  object
#  4   RECEIVED_COMMUNICATION  35884 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# El dataset no tiene valores nulos.

# %% [markdown]
# **Dataset basic statistical data**

# %%
clients.describe().T
# Out:
#                           count          mean           std         min  \
# CLIENT ID               35884.0  2.706058e+07  8.835076e+06  18073108.0
# CLIENT_SEGMENT          35884.0  3.123593e+00  1.512932e+00         1.0
# RECEIVED_COMMUNICATION  35884.0  5.079980e-01  4.999430e-01         0.0
#
#                                 25%         50%          75%         max
# CLIENT ID               20533114.25  24621903.0  32985383.25  48365940.0
# CLIENT_SEGMENT                 2.00         3.0         4.00         6.0
# RECEIVED_COMMUNICATION         0.00         1.0         1.00         1.0

# %% [markdown]
# #### Variables

# %% [markdown]
# El dataset de clientes 'CLIENT TABLE' contiene las siguientes variables:
#
# **CLIENT ID**: Identificador único del cliente. (identificador)
#
# **CLIENT_SEGMENT**: Segmento de clientes (Categorica)
#
# **AVG CONSO**: Consumo medio mensual del cliente calculado a finales de 2020 (en piezas de fruta) (Numérica)
#
# **AVG BASKET SIZE**: Tamaño medio de la cesta del cliente calculado a finales de 2020 (en piezas de fruta) (Numérica)
#
# **RECEIVED_COMMUNICATION**: 1 = Recibió promoción de sus productos / 0 = no la recibió (Boleana)

# %%
clients.columns
# Out:
# Index(['CLIENT ID', 'CLIENT_SEGMENT', 'AVG CONSO', 'AVG BASKET SIZE',
#        'RECEIVED_COMMUNICATION'],
#       dtype='object')

# %% [markdown]
# Las columnas tienen espacios en blanco en los nombres que cambio por "underscores" y putualizo un nombre de columna para que sea más explicativo.

# %%
clients.columns = ['CLIENT_ID', 'CLIENT_SEGMENT', 'AVG_CONSO_MONTH', 'AVG_BASKET_SIZE',
       'RECEIVED_COMMUNICATION']

# %%
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35884 entries, 0 to 35883
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLIENT_ID               35884 non-null  int64
#  1   CLIENT_SEGMENT          35884 non-null  int64
#  2   AVG_CONSO_MONTH         35884 non-null  object
#  3   AVG_BASKET_SIZE         35884 non-null  object
#  4   RECEIVED_COMMUNICATION  35884 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# El dataset de clientes no tiene valores nulos.
# Algunas variables no tienen el tipo corecto, las corrijo.

# %%
clients['CLIENT_ID'] = clients['CLIENT_ID'].astype(object)

# %%
clients['AVG_CONSO_MONTH'] = pd.to_numeric(clients['AVG_CONSO_MONTH'].str.replace(',','.'))

# %%
clients['AVG_BASKET_SIZE'] = pd.to_numeric(clients['AVG_BASKET_SIZE'].str.replace(',','.'))

# %%
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35884 entries, 0 to 35883
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLIENT_ID               35884 non-null  object
#  1   CLIENT_SEGMENT          35884 non-null  int64
#  2   AVG_CONSO_MONTH         35884 non-null  float64
#  3   AVG_BASKET_SIZE         35884 non-null  float64
#  4   RECEIVED_COMMUNICATION  35884 non-null  int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.4+ MB

# %%
clients.head()
# Out:
#   CLIENT_ID  CLIENT_SEGMENT  AVG_CONSO_MONTH  AVG_BASKET_SIZE  \
# 0  24321771               6            67.25           201.75
# 1  24321859               2            58.33           350.00
# 2  24321880               3            46.67           112.00
# 3  24321957               2            50.00           600.00
# 4  24321962               4            10.00           120.00
#
#    RECEIVED_COMMUNICATION
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# ##### CLIENT_ID

# %%
clients['CLIENT_ID'].count()
# Out:
# 35884

# %%
len(clients['CLIENT_ID'].unique())
# Out:
# 35884

# %%
clients['CLIENT_ID'].min()
# Out:
# 18073108

# %%
clients['CLIENT_ID'].max()
# Out:
# 48365940

# %% [markdown]
# **Todos los id de clientes son únicos, hay 35.884 y van desde '18073108' a '48365940'**

# %% [markdown]
# ##### CLIENT_SEGMENT (TARGET)

# %%
clients['CLIENT_SEGMENT'].unique()
# Out:
# array([6, 2, 3, 4, 5, 1])

# %% [markdown]
# **Los tipos de clientes van de 1 a 6**

# %%
segments = clients[['CLIENT_SEGMENT', 'CLIENT_ID']].groupby('CLIENT_SEGMENT').count().reset_index()
segments
# Out:
#    CLIENT_SEGMENT  CLIENT_ID
# 0               1       6505
# 1               2       6760
# 2               3       8123
# 3               4       7927
# 4               5       3429
# 5               6       3140

# %%
_ = sns.barplot(data = segments, x='CLIENT_SEGMENT', y='CLIENT_ID')
plt.title("CLIENTS SEGMENT DISTRIBUTION HISTOGRAM", fontsize='16')
plt.show()

# %% [markdown]
# Hay 6 Segmentpos, bastante desbalanceados:
# * los segmentos 3 y 4 con aproximadamente 8.000 registros.
# * los segmentos 1 y 2 con aproximadamente 6.500 registros.
# * los segmentos 5 y 6 con aproximadamente 3.000 registros.

# %% [markdown]
# ##### AVG_CONSO_MONTH

# %%
clients['AVG_CONSO_MONTH'].min()
# Out:
# 0.83

# %%
clients['AVG_CONSO_MONTH'].median()
# Out:
# 50.0

# %%
clients['AVG_CONSO_MONTH'].mean()
# Out:
# 64.53443679634394

# %%
clients['AVG_CONSO_MONTH'].max()
# Out:
# 2433.33

# %% [markdown]
# Los consumos mensuales medios, van de un minimo de 0,83 al mes a un máximo de 2.433,33, siendo 50 la mediana y 64,53 la media.

# %%
_ = sns.histplot(clients['AVG_CONSO_MONTH'])
plt.title("AVERAGE SPENDING PER MONTH DISTRIBUTION HISTOGRAM", fontsize='16')
plt.show()

# %% [markdown]
# La distribución está sesgada a la derecha y tiene una kurtosis positiva.

# %%
_ = sns.boxplot(x="CLIENT_SEGMENT", y="AVG_CONSO_MONTH", data=clients)
plt.title("BOXPLOT SPENDING PER MONTH BY CLIENT SEGMENT", fontsize='16')
plt.xlabel("CLIENT SEGMENTS")
plt.ylabel("AVERAGE CONSOPTION MONTH")
plt.show()

# %% [markdown]
# Los boxplot nos muestran que las distribuciones intragemento tienen poca variabilidad.
#
# También podemos observar que el segmento 6 tiene outliers.

# %% [markdown]
# ##### AVG_BASKET_SIZE

# %%
clients['AVG_BASKET_SIZE'].min()
# Out:
# 10.0

# %%
clients['AVG_BASKET_SIZE'].median()
# Out:
# 160.0

# %%
clients['AVG_BASKET_SIZE'].mean()
# Out:
# 181.21860968676924

# %%
clients['AVG_BASKET_SIZE'].max()
# Out:
# 3400.2

# %% [markdown]
# La cesta media de cliente va de 10 productos (siendo un prod, 10 piezas de fruta, es lógico que no haya canridades inferiores) a 3400.2 piezas de fruta, siendo 160 piezas la mediana y 181.22 la media.

# %%
_ = sns.histplot(data=clients['AVG_BASKET_SIZE'])
plt.title("AVERAGE BARKET SIZE PER MONTH DISTRIBUTION HISTOGRAM", fontsize='16')
plt.show()

# %% [markdown]
# La distribución está sesgada a la derecha y tiene una kutosis negativa.

# %%
_ = sns.boxplot(x="CLIENT_SEGMENT", y="AVG_BASKET_SIZE", data=clients)
plt.title("BOXPLOT BASKET SIZE PER MONTH BY CLIENT SEGMENT", fontsize='16')
plt.xlabel("CLIENT SEGMENTS")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %% [markdown]
# Las distribuciones de la cesta media de productos sigue siendo poco variable por segmento.
#
# Los segmentos 6 y el 2 tienen outliers.

# %%
_ = sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients, hue='CLIENT_SEGMENT', palette="Set1")
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE BY SEGMENT", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %% [markdown]
# En el scatterplot vemos que las variables tienen cierta correlación lineal, y que algunos segmentos parecen distinguirse en algunas zonas del mismo. Con algunos outliers.

# %% [markdown]
# Estudiamos cada segmento por separado

# %%
_ = sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients[clients['CLIENT_SEGMENT']==1], color='b')
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE SEGMENT 1 ", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %%
sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients[clients['CLIENT_SEGMENT']==2], color='orange')
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE SEGMENT 2 ", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %%
sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients[clients['CLIENT_SEGMENT']==3], color='g')
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE SEGMENT 3", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %%
sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients[clients['CLIENT_SEGMENT']==4], color='r')
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE SEGMENT 4 ", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %%
sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients[clients['CLIENT_SEGMENT']==5], color='grey')
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE SEGMENT 5 ", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %%
sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients[clients['CLIENT_SEGMENT']==6], color='brown')
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE SEGMENT 6", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %% [markdown]
# ##### RECEIVED_COMMUNICATION

# %%
rec_com = clients[['RECEIVED_COMMUNICATION', 'CLIENT_ID']].groupby(by=['RECEIVED_COMMUNICATION']).count().reset_index()
rec_com
# Out:
#    RECEIVED_COMMUNICATION  CLIENT_ID
# 0                       0      17655
# 1                       1      18229

# %%
_ = sns.barplot(data=rec_com, y='CLIENT_ID', x='RECEIVED_COMMUNICATION')
plt.title("RECECIVED COMUNICATION", fontsize='16')
plt.xlabel("RECEIVED COMUNICATION")
plt.ylabel("COUNT")
plt.show()

# %% [markdown]
# Aproximadamente el 50% de los clientes han recibido una comunicación.

# %%
rec_com_seg = clients[['RECEIVED_COMMUNICATION', 'CLIENT_ID', 'CLIENT_SEGMENT']].groupby(by=['RECEIVED_COMMUNICATION','CLIENT_SEGMENT']).count().reset_index()
rec_com_seg
# Out:
#     RECEIVED_COMMUNICATION  CLIENT_SEGMENT  CLIENT_ID
# 0                        0               1       2723
# 1                        0               2       2960
# 2                        0               3       3699
# 3                        0               4       4384
# 4                        0               5       2577
# 5                        0               6       1312
# 6                        1               1       3782
# 7                        1               2       3800
# 8                        1               3       4424
# 9                        1               4       3543
# 10                       1               5        852
# 11                       1               6       1828

# %%
_ = sns.barplot(data=rec_com_seg, y='CLIENT_ID', x='CLIENT_SEGMENT', hue='RECEIVED_COMMUNICATION')
plt.title("RECECIVED COMUNICATION PER SEGMENT", fontsize='16')
plt.xlabel("SEGMENT / RECEDIVED COMMUNICATION")
plt.ylabel("COUNT")
plt.show()

# %% [markdown]
# Para los diferentes segmentos las clases "received comunnication" y "Not received communication", están bastante equilibradas excepto en el segmento 5.

# %%
_ = sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients, hue='RECEIVED_COMMUNICATION', palette="Set1")
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE, BY RECEIVED COMMUNICATION", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %%
sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients[clients['RECEIVED_COMMUNICATION']==0], color='r')
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE, NOT RECEIVED COMMUNICATION", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %%
_ = sns.scatterplot(x="AVG_CONSO_MONTH", y="AVG_BASKET_SIZE", data=clients[clients['RECEIVED_COMMUNICATION']==1], color='b')
plt.title("AVERAGE CONSOMPTION vs AVERAGE BASKET SIZE, RECEIVED COMMUNICATION", fontsize='16')
plt.xlabel("AVERAGE CONSOMTION PER MONTH")
plt.ylabel("AVERAGE BASKET SIZE")
plt.show()

# %% [markdown]
# #### Correlaciones

# %%
_ = sns.pairplot(clients)
plt.show()

# %% [markdown]
# Las variables AVERAGE CONSOMPTION y AVERAGE BASKET SIZE SEGMENT parece que están correlacionadas.

# %%
mask = np.triu(np.ones_like(clients.corr(), dtype=bool))
sns.heatmap(clients.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Triangle Correlation Heatmap', fontsize=16)
plt.show()

# %% [markdown]
# ### Dataset de Orders

# %% [markdown]
# #### Exploración Inicial

# %%
orders.head()
# Out:
#    CLIENT ID  NB PRODS   ORDER ID FRUIT_PRODUCT
# 0   18070505         5  671907264         Apple
# 1   18070505        10  671907264        Orange
# 2   18070505         5  671907264          Kiwi
# 3   18070505        10  671907264          Pear
# 4   18070505         5  671907264        Cheery

# %%
orders.shape
# Out:
# (66912, 4)

# %% [markdown]
# El dataset de pedidos tiene 66.912 registros y 4 variables.

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66912 entries, 0 to 66911
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CLIENT ID      66912 non-null  int64
#  1   NB PRODS       66912 non-null  int64
#  2   ORDER ID       66912 non-null  int64
#  3   FRUIT_PRODUCT  66912 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 2.0+ MB

# %% [markdown]
# El dataset no tiene valores nulos

# %% [markdown]
# **Datos estadísticos básicos**

# %%
orders.describe().T
# Out:
#              count          mean           std          min          25%  \
# CLIENT ID  66912.0  2.613407e+07  8.473596e+06   18070505.0   20174269.0
# NB PRODS   66912.0  4.528112e+00  5.788227e+00        -80.0          1.0
# ORDER ID   66912.0  6.722533e+08  3.205826e+06  663833537.0  669480300.0
#
#                    50%          75%          max
# CLIENT ID   24380549.0   25387075.0   48365861.0
# NB PRODS           3.0          5.0        198.0
# ORDER ID   671997144.0  675089335.0  683213167.0

# %% [markdown]
# #### Variables

# %% [markdown]
# El dataset de pedidos 'ORDERS TABLE' contiene las siguientes variables:
#
# **CLIENT ID**: Identificador único del cliente. (identificador)
#
# **NB PRODS**: Número de 'prods' de la variedad de fruta en el pedido (1 prod = 10 piezas de fruta) (Numérico)
#
# **ORDER ID**: Identificador único del pedido.(identificador)
#
# **FRUIT_PRODUCT**: Variedad de fruta. (Categorico)

# %%
orders.columns
# Out:
# Index(['CLIENT ID', 'NB PRODS', 'ORDER ID', 'FRUIT_PRODUCT'], dtype='object')

# %% [markdown]
# Las columnas tienen espacios en blanco en los nombres que cambio por "underscores" y putualizo un nombre de columna para que sea más explicativo.

# %%
orders.columns = ['CLIENT_ID','NUM_PRODS', 'ORDER_ID', 'FRUIT_PRODUCT']

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66912 entries, 0 to 66911
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CLIENT_ID      66912 non-null  int64
#  1   NUM_PRODS      66912 non-null  int64
#  2   ORDER_ID       66912 non-null  int64
#  3   FRUIT_PRODUCT  66912 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 2.0+ MB

# %% [markdown]
# El tipo de CLIENT_ID y ORDER_ID al ser IDs los cambiamos a object.

# %%
orders['CLIENT_ID'] = orders['CLIENT_ID'].astype(object)
orders['ORDER_ID'] = orders['ORDER_ID'].astype(object)

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66912 entries, 0 to 66911
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CLIENT_ID      66912 non-null  object
#  1   NUM_PRODS      66912 non-null  int64
#  2   ORDER_ID       66912 non-null  object
#  3   FRUIT_PRODUCT  66912 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# ##### CLIENT_ID

# %%
orders['CLIENT_ID'].count()
# Out:
# 66912

# %%
len(orders['CLIENT_ID'].unique())
# Out:
# 14499

# %%
orders['CLIENT_ID'].min()
# Out:
# 18070505

# %%
orders['CLIENT_ID'].max()
# Out:
# 48365861

# %% [markdown]
# Hay 14.499 id de clientes únicos, por tanto hay 21.385 clientes sin pedidos.

# %% [markdown]
# ##### NUM_PRODS

# %%
orders['NUM_PRODS'].sum()
# Out:
# 302985

# %% [markdown]
# El número total de productos comprados es 302.985

# %%
orders['NUM_PRODS'].min()
# Out:
# -80

# %% [markdown]
# El mínimo es -80, por tanto parece que hay abonos o errores.

# %%
orders['NUM_PRODS'].max()
# Out:
# 198

# %% [markdown]
# El máximo son 198 productos.

# %%
orders['NUM_PRODS'].median()
# Out:
# 3.0

# %%
orders['NUM_PRODS'].mean()
# Out:
# 4.528111549497848

# %% [markdown]
# La mediana de numero de productos es 3 y la media 4,53

# %%
_ = sns.histplot(orders['NUM_PRODS'], bins=100)
plt.title("NUM PRODS HISTOGRAM", fontsize='16')
plt.show()

# %%
_ = sns.boxplot(x=orders['NUM_PRODS'])
plt.title("NUM PRODS HISTOGRAM", fontsize='16')
plt.show()

# %% [markdown]
# El número de productos pedido por los clientes tiene poca variación y algunos ouliers tanto positivos como negativos.

# %%
len(orders['NUM_PRODS'][orders['NUM_PRODS']<0])
# Out:
# 362

# %%
len(orders['NUM_PRODS'][orders['NUM_PRODS']>0])
# Out:
# 66550

# %%
orders[orders['NUM_PRODS']<0].iloc[:1]
# Out:
#     CLIENT_ID  NUM_PRODS   ORDER_ID FRUIT_PRODUCT
# 185  18090840        -40  667141810     Nectarine

# %%
orders[orders['CLIENT_ID']==18090840]
# Out:
#     CLIENT_ID  NUM_PRODS   ORDER_ID FRUIT_PRODUCT
# 183  18090840         40  667141810     Nectarine
# 184  18090840         40  673547644     Nectarine
# 185  18090840        -40  667141810     Nectarine

# %% [markdown]
# El número de pedidos con productos negarivos es un 0,005%.
#
# Observando el cliente 18090840, podemos deducir que son abonos de devoluciones de los clientes.

# %% [markdown]
# ##### ORDER_ID

# %%
orders['ORDER_ID'].count()
# Out:
# 66912

# %%
len(orders['ORDER_ID'].unique())
# Out:
# 17458

# %%
orders['ORDER_ID'].min()
# Out:
# 663833537

# %%
orders['ORDER_ID'].max()
# Out:
# 683213167

# %%
len(orders['ORDER_ID'].unique())/len(orders['CLIENT_ID'].unique())
# Out:
# 1.2040830402096696

# %%
orders['NUM_PRODS'].sum()  / len(orders['ORDER_ID'].unique())
# Out:
# 17.355080765265207

# %%
orders['NUM_PRODS'].sum()  / len(orders['CLIENT_ID'].unique())
# Out:
# 20.896958410924892

# %% [markdown]
# La media de productos por pedido es 17,35 y la media de productos por cliente unico es de 20,90

# %% [markdown]
# ##### FRUIT_PRODUCT

# %%
orders['FRUIT_PRODUCT'].unique()
# Out:
# array(['Apple', 'Orange', 'Kiwi', 'Pear', 'Cheery', 'Watermelon',
#        'Strawberry', 'Nectarine', 'Grape', 'Mango', 'Blueberry',
#        'Pomegranate', 'Nuwe Fruit', 'Devil Fruit', 'Plum', 'Papaya',
#        'Jackfruit', 'Pineapple', 'Lemon', 'Lime', 'Apricot', 'Coconut',
#        'Melon', 'Banana'], dtype=object)

# %%
orders['FRUIT_PRODUCT'].value_counts()
# Out:
# Kiwi           6431
# Orange         5997
# Lemon          5664
# Cheery         4071
# Nuwe Fruit     3688
# Pear           3682
# Nectarine      3520
# Apple          3439
# Banana         3408
# Grape          3126
# Coconut        2429
# Apricot        2277
# Devil Fruit    2173
# Papaya         1944
# Mango          1839
# Plum           1788
# Blueberry      1696
# Lime           1656
# Strawberry     1642
# Pomegranate    1623
# Watermelon     1411
# Melon          1345
# Pineapple      1273
# Jackfruit       790
# Name: FRUIT_PRODUCT, dtype: int64

# %%
fruits = orders[['FRUIT_PRODUCT', 'ORDER_ID']].groupby(by=['FRUIT_PRODUCT']).count().reset_index()
fruits
# Out:
#    FRUIT_PRODUCT  ORDER_ID
# 0          Apple      3439
# 1        Apricot      2277
# 2         Banana      3408
# 3      Blueberry      1696
# 4         Cheery      4071
# 5        Coconut      2429
# 6    Devil Fruit      2173
# 7          Grape      3126
# 8      Jackfruit       790
# 9           Kiwi      6431
# 10         Lemon      5664
# 11          Lime      1656
# 12         Mango      1839
# 13         Melon      1345
# 14     Nectarine      3520
# 15    Nuwe Fruit      3688
# 16        Orange      5997
# 17        Papaya      1944
# 18          Pear      3682
# 19     Pineapple      1273
# 20          Plum      1788
# 21   Pomegranate      1623
# 22    Strawberry      1642
# 23    Watermelon      1411

# %%
_ = sns.barplot(data=fruits, x='FRUIT_PRODUCT', y='ORDER_ID')
plt.title("FRUIT BY ORDER", fontsize='16')
plt.xlabel("FRUITS")
plt.ylabel("NUMER OF ORDERS")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Las frutas que aparecen en más pedidos son el kiwi, la naranja y el limón.
# La comprada en menos pedidos en la jaca.

# %%
total_fruits = orders[['FRUIT_PRODUCT', 'NUM_PRODS', ]].groupby(by=['FRUIT_PRODUCT']).sum().reset_index()
total_fruits
# Out:
#    FRUIT_PRODUCT  NUM_PRODS
# 0          Apple       6637
# 1        Apricot       9774
# 2         Banana      17662
# 3      Blueberry       4523
# 4         Cheery      26797
# 5        Coconut      11862
# 6    Devil Fruit       6071
# 7          Grape       6581
# 8      Jackfruit       2339
# 9           Kiwi      36011
# 10         Lemon      34061
# 11          Lime       5881
# 12         Mango       5187
# 13         Melon       3403
# 14     Nectarine      18934
# 15    Nuwe Fruit      19846
# 16        Orange      33145
# 17        Papaya       8286
# 18          Pear      22776
# 19     Pineapple       3873
# 20          Plum       3826
# 21   Pomegranate       4945
# 22    Strawberry       6269
# 23    Watermelon       4296

# %%
_ = sns.barplot(data=total_fruits, x='FRUIT_PRODUCT', y='NUM_PRODS')
plt.title("TOTAL FRUITS", fontsize='16')
plt.xlabel("FRUITS")
plt.ylabel("NUMER OF FRUITS")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Las frutas más compradas son también los kiwis, naranjas y limones.
# Las frutas menos comprada es la yaca.

# %% [markdown]
# ### Juntamos las tablas

# %%
clients.head()
# Out:
#   CLIENT_ID  CLIENT_SEGMENT  AVG_CONSO_MONTH  AVG_BASKET_SIZE  \
# 0  24321771               6            67.25           201.75
# 1  24321859               2            58.33           350.00
# 2  24321880               3            46.67           112.00
# 3  24321957               2            50.00           600.00
# 4  24321962               4            10.00           120.00
#
#    RECEIVED_COMMUNICATION
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
orders.head()
# Out:
#   CLIENT_ID  NUM_PRODS   ORDER_ID FRUIT_PRODUCT
# 0  18070505          5  671907264         Apple
# 1  18070505         10  671907264        Orange
# 2  18070505          5  671907264          Kiwi
# 3  18070505         10  671907264          Pear
# 4  18070505          5  671907264        Cheery

# %%
data = pd.merge(orders, clients, on='CLIENT_ID')

# %%
data.head()
# Out:
#   CLIENT_ID  NUM_PRODS   ORDER_ID FRUIT_PRODUCT  CLIENT_SEGMENT  \
# 0  18073169          3  675518868          Kiwi               6
# 1  18073169          4  675518868         Lemon               6
# 2  18073169          7  675518868        Cheery               6
# 3  18073169          8  675518868    Nuwe Fruit               6
# 4  18073169          3  675518868          Kiwi               6
#
#    AVG_CONSO_MONTH  AVG_BASKET_SIZE  RECEIVED_COMMUNICATION
# 0             50.0            150.0                       1
# 1             50.0            150.0                       1
# 2             50.0            150.0                       1
# 3             50.0            150.0                       1
# 4             50.0            150.0                       1

# %%
data.shape
# Out:
# (66872, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66872 entries, 0 to 66871
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLIENT_ID               66872 non-null  object
#  1   NUM_PRODS               66872 non-null  int64
#  2   ORDER_ID                66872 non-null  object
#  3   FRUIT_PRODUCT           66872 non-null  object
#  4   CLIENT_SEGMENT          66872 non-null  int64
#  5   AVG_CONSO_MONTH         66872 non-null  float64
#  6   AVG_BASKET_SIZE         66872 non-null  float64
#  7   RECEIVED_COMMUNICATION  66872 non-null  int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 4.6+ MB

# %%
data.describe().T
# Out:
#                           count        mean         std    min     25%  \
# NUM_PRODS               66872.0    4.528039    5.789459 -80.00    1.00
# CLIENT_SEGMENT          66872.0    2.610270    1.598013   1.00    1.00
# AVG_CONSO_MONTH         66872.0   94.611493   87.914963   0.83   42.83
# AVG_BASKET_SIZE         66872.0  192.236892  126.385964  10.00  108.33
# RECEIVED_COMMUNICATION  66872.0    0.575727    0.494236   0.00    0.00
#
#                            50%     75%      max
# NUM_PRODS                 3.00    5.00   198.00
# CLIENT_SEGMENT            2.00    4.00     6.00
# AVG_CONSO_MONTH          76.67  123.92  2433.33
# AVG_BASKET_SIZE         175.00  233.33  2654.55
# RECEIVED_COMMUNICATION    1.00    1.00     1.00

# %%
_ = sns.pairplot(data, hue="RECEIVED_COMMUNICATION")

# %%
mask = np.triu(np.ones_like(data.corr(), dtype=bool))
sns.heatmap(data.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.title('Triangle Correlation Heatmap', fontsize=16)
plt.show()

# %% [markdown]
# No detecto colinearidad en ningún par de variables.

# %% [markdown]
# #### Received comunication

# %%
data.head()
# Out:
#   CLIENT_ID  NUM_PRODS   ORDER_ID FRUIT_PRODUCT  CLIENT_SEGMENT  \
# 0  18073169          3  675518868          Kiwi               6
# 1  18073169          4  675518868         Lemon               6
# 2  18073169          7  675518868        Cheery               6
# 3  18073169          8  675518868    Nuwe Fruit               6
# 4  18073169          3  675518868          Kiwi               6
#
#    AVG_CONSO_MONTH  AVG_BASKET_SIZE  RECEIVED_COMMUNICATION
# 0             50.0            150.0                       1
# 1             50.0            150.0                       1
# 2             50.0            150.0                       1
# 3             50.0            150.0                       1
# 4             50.0            150.0                       1

# %%
rec_com_tot = data[['RECEIVED_COMMUNICATION', 'NUM_PRODS', 'CLIENT_SEGMENT']].groupby(by=['RECEIVED_COMMUNICATION','CLIENT_SEGMENT']).sum().reset_index()
rec_com_tot
# Out:
#     RECEIVED_COMMUNICATION  CLIENT_SEGMENT  NUM_PRODS
# 0                        0               1      41761
# 1                        0               2      30618
# 2                        0               3      17804
# 3                        0               4       9761
# 4                        0               5       2516
# 5                        0               6      13568
# 6                        1               1      67520
# 7                        1               2      47569
# 8                        1               3      29277
# 9                        1               4      10768
# 10                       1               5        990
# 11                       1               6      30647

# %%
sns.boxplot(data=rec_com_tot, x='RECEIVED_COMMUNICATION', y='NUM_PRODS')
plt.show()

# %%
sns.violinplot(data=rec_com_tot, x='RECEIVED_COMMUNICATION', y='NUM_PRODS')
plt.show()

# %%
_ = sns.barplot(data=rec_com_tot, y='NUM_PRODS', x='CLIENT_SEGMENT', hue='RECEIVED_COMMUNICATION')
plt.title("RECECIVED COMUNICATION PER SEGMENT, TOTAL PRODUCTS", fontsize='16')
plt.xlabel("SEGMENT / RECEDIVED COMMUNICATION")
plt.ylabel("SUM TOTAL PRODUCTS")
plt.show()

# %% [markdown]
# En casi todos los segmentos hay un incremento del total de productos pedidos si el cliente ha recibido una comunicación, excepto en el segmento 5.

# %% [markdown]
# ## PREDICCIÓN SEGMENTOS

# %%
train = clients.copy()

# %%
train.head()
# Out:
#   CLIENT_ID  CLIENT_SEGMENT  AVG_CONSO_MONTH  AVG_BASKET_SIZE  \
# 0  24321771               6            67.25           201.75
# 1  24321859               2            58.33           350.00
# 2  24321880               3            46.67           112.00
# 3  24321957               2            50.00           600.00
# 4  24321962               4            10.00           120.00
#
#    RECEIVED_COMMUNICATION
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# ### Train Test Split

# %%
X = train.drop(['CLIENT_ID','CLIENT_SEGMENT'], axis=1)
y = train['CLIENT_SEGMENT']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=5, stratify=y)

# %%
features = train.drop(['CLIENT_ID','CLIENT_SEGMENT'], axis=1).columns

# %% [markdown]
# ### Separabilidad de las clases

# %%
x_tsne = TSNE().fit_transform(X)

# %%
plt.scatter(x_tsne[:,0], x_tsne[:,1], c=y)
plt.show()

# %% [markdown]
# ###  Random Forest Classifier

# %%
rf = RandomForestClassifier(random_state = 5)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=5)

# %%
rf.score(X_train, y_train)
# Out:
# 0.8212631065593757

# %%
rf.score(X_test, y_test)
# Out:
# 0.7600668803121081

# %% [markdown]
# El modelo parece un poco overfiteado, ya que predice 6 puntos mejor el trsain que el test.

# %%
y_pred = rf.predict(X_test)

# %%
_ = sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot=True,  
            cmap=plt.cm.Blues,
                yticklabels=[1,2,3,4,5,6],
                xticklabels=[1,2,3,4,5,6],
               fmt='g')
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.86      0.91      0.89      1301
#            2       0.79      0.88      0.83      1352
#            3       0.75      0.79      0.77      1625
#            4       0.74      0.75      0.74      1585
#            5       0.69      0.82      0.75       686
#            6       0.26      0.07      0.11       628
#
#     accuracy                           0.76      7177
#    macro avg       0.68      0.70      0.68      7177
# weighted avg       0.73      0.76      0.74      7177

# %% [markdown]
# Vemos que la clase 6 es la que más le cuesta predecir, y recordemos era la que tenía más ooutliers.

# %%
fi = pd.DataFrame([rf.feature_importances_],columns=features)
fi
# Out:
#    AVG_CONSO_MONTH  AVG_BASKET_SIZE  RECEIVED_COMMUNICATION
# 0         0.641586         0.348144                0.010269

# %%
sns.barplot(data=fi)
plt.show()

# %% [markdown]
# La feature AVG_CONSO_MONTH es la más importante en la predicción.

# %% [markdown]
# ### Gradient Boosting

# %%
gb = GradientBoostingClassifier(random_state = 5)

# %%
gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=5)

# %%
gb.score(X_train, y_train)
# Out:
# 0.7929076531856342

# %%
gb.score(X_test, y_test)
# Out:
# 0.769959593144768

# %% [markdown]
# En este caso los resultados son muy similares pero con menos overfitting.

# %%
y_pred = gb.predict(X_test)

# %%
_ = sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot=True,  
            cmap=plt.cm.Blues,
                yticklabels=[1,2,3,4,5,6],
                xticklabels=[1,2,3,4,5,6],
               fmt='g')
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.87      0.94      0.90      1301
#            2       0.82      0.88      0.85      1352
#            3       0.74      0.82      0.78      1625
#            4       0.74      0.74      0.74      1585
#            5       0.69      0.83      0.75       686
#            6       0.44      0.05      0.09       628
#
#     accuracy                           0.77      7177
#    macro avg       0.71      0.71      0.68      7177
# weighted avg       0.75      0.77      0.74      7177

# %% [markdown]
# Hemos mejorado del 71,56% al 77,42% Vemos que la clase 6 también cuesta predecirla.

# %%
fi = pd.DataFrame([gb.feature_importances_],columns=features)
fi
# Out:
#    AVG_CONSO_MONTH  AVG_BASKET_SIZE  RECEIVED_COMMUNICATION
# 0         0.716351         0.274922                0.008727

# %%
sns.barplot(data=fi)
plt.show()

# %% [markdown]
# La feature AVG_CONSO_MONTH es la más importante en la predicción.

# %% [markdown]
# ### ExtraTreeClassifier

# %%
et = ExtraTreesClassifier(random_state = 5)

# %%
et.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=5)

# %%
et.score(X_train, y_train)
# Out:
# 0.8212979412686802

# %%
et.score(X_test, y_test)
# Out:
# 0.7576982025916121

# %% [markdown]
# En este caso los resultados son peores y con más overfitting.

# %%
y_pred = et.predict(X_test)

# %%
_ = sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot=True,  
            cmap=plt.cm.Blues,
                yticklabels=[1,2,3,4,5,6],
                xticklabels=[1,2,3,4,5,6],
               fmt='g')
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.86      0.91      0.88      1301
#            2       0.79      0.90      0.84      1352
#            3       0.75      0.79      0.77      1625
#            4       0.74      0.74      0.74      1585
#            5       0.69      0.82      0.75       686
#            6       0.24      0.06      0.10       628
#
#     accuracy                           0.76      7177
#    macro avg       0.68      0.70      0.68      7177
# weighted avg       0.72      0.76      0.73      7177

# %% [markdown]
# Vemos que la clase 6 también cuesta predecirla.

# %% [markdown]
# ### Standard Scaler

# %% [markdown]
# Añadimos un escalado, para disminuir el efecto de los ourliers.

# %%
scaler = StandardScaler()

# %%
transformer = scaler.fit(X_train)
X_train = transformer.transform(X_train)
X_test = transformer.transform(X_test)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=5)

# %%
rf.score(X_train, y_train)
# Out:
# 0.8212631065593757

# %%
rf.score(X_test, y_test)
# Out:
# 0.7597882123449909

# %%
gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=5)

# %%
gb.score(X_train, y_train)
# Out:
# 0.7929076531856342

# %%
gb.score(X_test, y_test)
# Out:
# 0.7700989271283266

# %%
et.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=5)

# %%
et.score(X_train, y_train)
# Out:
# 0.8212979412686802

# %%
et.score(X_test, y_test)
# Out:
# 0.7576982025916121

# %% [markdown]
# El Gradient Boost nos sigue dando un mejor resultado con un 77,01%

# %%
y_pred = gb.predict(X_test)

# %%
_ = sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot=True,  
            cmap=plt.cm.Blues,
                yticklabels=[1,2,3,4,5,6],
                xticklabels=[1,2,3,4,5,6],
               fmt='g')
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.87      0.94      0.90      1301
#            2       0.82      0.88      0.85      1352
#            3       0.74      0.82      0.78      1625
#            4       0.74      0.74      0.74      1585
#            5       0.69      0.83      0.75       686
#            6       0.44      0.05      0.09       628
#
#     accuracy                           0.77      7177
#    macro avg       0.71      0.71      0.69      7177
# weighted avg       0.75      0.77      0.74      7177

# %% [markdown]
# Hemos mejorado considerablemente la precisión de la clase 6, aunque aún tenemos probleams con el recall.

# %% [markdown]
# ### Grsadient Boosting Fine Tunning

# %%
print('Parameters que hemos usado en el mejor modelo:\n')
print(gb.get_params())
# Out:
# Parameters que hemos usado en el mejor modelo:
#
# {'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_iter_no_change': None, 'random_state': 5, 'subsample': 1.0, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}

# %%
param_grid = {
'learning_rate' : [0.2, 0.1],
'n_estimators' :[100, 200],
'max_depth' : [3, 5],
}

# %%
gbhyper = GradientBoostingClassifier(random_state = 5)

# %%
grid_search = GridSearchCV(estimator = gbhyper,
                           param_grid = param_grid,
                           cv = 3, 
                           n_jobs = -1, 
                           verbose = 3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(random_state=5),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.2, 0.1], 'max_depth': [3, 5],
#                          'n_estimators': [100, 200]},
#              verbose=3)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}

# %%
best_grid = grid_search.best_estimator_

# %%
best_grid.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=5)

# %%
print('Parameters que hemos usado en el modelo de Random Forrest con Hypertunning:\n')
print(best_grid.get_params())
# Out:
# Parameters que hemos usado en el modelo de Random Forrest con Hypertunning:
#
# {'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_iter_no_change': None, 'random_state': 5, 'subsample': 1.0, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}

# %%
best_grid.score(X_train, y_train)
# Out:
# 0.7929076531856342

# %%
best_grid.score(X_test, y_test)
# Out:
# 0.7700989271283266

# %%
y_pred = best_grid.predict(X_test)

# %%
_ = sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot=True,  
            cmap=plt.cm.Blues,
                yticklabels=[1,2,3,4,5,6],
                xticklabels=[1,2,3,4,5,6])
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.87      0.94      0.90      1301
#            2       0.82      0.88      0.85      1352
#            3       0.74      0.82      0.78      1625
#            4       0.74      0.74      0.74      1585
#            5       0.69      0.83      0.75       686
#            6       0.44      0.05      0.09       628
#
#     accuracy                           0.77      7177
#    macro avg       0.71      0.71      0.69      7177
# weighted avg       0.75      0.77      0.74      7177

# %% [markdown]
# El Grid Search Cross Validation escogido los mismos parámetros que ya teníamos.

# %% [markdown]
# ## Resultados

# %%
test = pd.read_csv("data/mwc22-client_table+-+test_x.csv")

# %%
test.head()
# Out:
#    CLIENT ID AVG CONSO AVG BASKET SIZE  RECEIVED_COMMUNICATION
# 0   48352078      8,33             100                       0
# 1   18072186     93,42          186,83                       1
# 2   48352246     45,83           137,5                       0
# 3   18070621     16,67             200                       1
# 4   48352262     13,33             160                       0

# %%
example = pd.read_csv("data/Example__results.csv")

# %%
example.head()
# Out:
#    CLIENT ID  CLIENT_SEGMENT
# 0   48352078               1
# 1   18072186               2
# 2   48352246               1
# 3   18070621               5
# 4   48352262               3

# %%
results = pd.DataFrame(columns=['CLIENT ID','CLIENT_SEGMENT'])

# %%
validation = test.copy()

# %%
validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLIENT ID               19 non-null     int64
#  1   AVG CONSO               19 non-null     object
#  2   AVG BASKET SIZE         19 non-null     object
#  3   RECEIVED_COMMUNICATION  19 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 736.0+ bytes

# %%
validation.columns = ['CLIENT_ID', 'AVG_CONSO_MONTH', 'AVG_BASKET_SIZE','RECEIVED_COMMUNICATION']

# %%
validation = validation.drop(['CLIENT_ID'], axis=1)

# %%
validation['AVG_CONSO_MONTH'] = pd.to_numeric(validation['AVG_CONSO_MONTH'].str.replace(',','.'))

# %%
validation['AVG_BASKET_SIZE'] = pd.to_numeric(validation['AVG_BASKET_SIZE'].str.replace(',','.'))

# %%
validation.head()
# Out:
#    AVG_CONSO_MONTH  AVG_BASKET_SIZE  RECEIVED_COMMUNICATION
# 0             8.33           100.00                       0
# 1            93.42           186.83                       1
# 2            45.83           137.50                       0
# 3            16.67           200.00                       1
# 4            13.33           160.00                       0

# %%
validation = transformer.transform(validation)

# %%
y_val_pred = best_grid.predict(validation)

# %%
results['CLIENT ID'] = test['CLIENT ID']

# %%
results['CLIENT_SEGMENT'] = y_val_pred

# %%
results.head()
# Out:
#    CLIENT ID  CLIENT_SEGMENT
# 0   48352078               5
# 1   18072186               1
# 2   48352246               3
# 3   18070621               4
# 4   48352262               4

# %%
results.to_csv("results.csv")
